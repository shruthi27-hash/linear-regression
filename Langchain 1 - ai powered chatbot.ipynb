# %%
import google.generativeai as genai
import gradio as gr

# 🔑 Enter your Gemini API key here
genai.configure(api_key="YOUR_API_KEY_HERE")

# Initialize Gemini Pro Model
model = genai.GenerativeModel("gemini-pro")

# Chat history setup
chat = model.start_chat(history=[])

# Chat function
def gemini_chat(user_input):
    response = chat.send_message(user_input)
    return response.text

# Gradio Interface
gr.ChatInterface(
    fn=gemini_chat,
    title="💬 Gemini Chatbot",
    description="Talk with Google's Gemini using a friendly interface!",
).launch()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-09851f88eb39> in <cell line: 0>()
#       1 import google.generativeai as genai
# ----> 2 import gradio as gr
#       3
#       4 # 🔑 Enter your Gemini API key here
#       5 genai.configure(api_key="YOUR_API_KEY_HERE")
#
# ModuleNotFoundError: No module named 'gradio'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import os
from langchain.chat_models import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain
import gradio as gr

# 🔑 Add your OpenAI API Key
os.environ["OPENAI_API_KEY"] = "your_openai_api_key_here"

# Setup LLM
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0.7)

# Setup memory
memory = ConversationBufferMemory()

# Setup conversational chain
conversation = ConversationChain(
    llm=llm,
    memory=memory,
    verbose=False
)

# Chat function
def chat_with_ai(user_input):
    return conversation.predict(input=user_input)

# Gradio interface
gr.ChatInterface(
    fn=chat_with_ai,
    title="🤖 LangChain AI Chatbot",
    description="A smart assistant powered by LangChain + OpenAI. Ask me anything!",
).launch()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a9d5c9dd286d> in <cell line: 0>()
#       1 import os
# ----> 2 from langchain.chat_models import ChatOpenAI
#       3 from langchain.schema import SystemMessage, HumanMessage
#       4 from langchain.memory import ConversationBufferMemory
#       5 from langchain.chains import ConversationChain
#
# /usr/local/lib/python3.11/dist-packages/langchain/chat_models/__init__.py in __getattr__(name)
#      27
#      28 def __getattr__(name: str) -> None:
# ---> 29     from langchain_community import chat_models
#      30
#      31     # If not in interactive env, raise warning.
#
# ModuleNotFoundError: No module named 'langchain_community'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# ...
